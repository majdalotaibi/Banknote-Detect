# %% [markdown]
# ### Banknote detect

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()

# %%
# load the dataset
data = pd.read_csv('Banknote.csv')
data
# Out:
#            V1        V2
# 0     3.62160   8.66610
# 1     4.54590   8.16740
# 2     3.86600  -2.63830
# 3     3.45660   9.52280
# 4     0.32924  -4.45520
# ...       ...       ...
# 1367  0.40614   1.34920
# 1368 -1.38870  -4.87730
# 1369 -3.75030 -13.45860
# 1370 -3.56370  -8.38270
# 1371 -2.54190  -0.65804
#
# [1372 rows x 2 columns]

# %%
v1D = data['V1']
v2D = data['V2']

# %% [markdown]
# ### Calculate statistical measures

# %%
# mean
v1_mean = np.mean(v1D)
v2_mean = np.mean(v2D)

# standard deviation
v1_std = np.std(v1D)
v2_std = np.std(v2D)

# max
v1_max = np.max(v1D)
v2_max = np.max(v2D)

# min 
v1_min = np.min(v1D)
v2_min = np.min(v2D)

print('-mean:\nV1:',v1_mean,
      '\nV2:',v2_mean,
      '\n-standard deviation:\nV1:',v1_std,
       '\nV2',v2_std,
       '\n-max:\nV1:',v1_max,
       '\nV2:',v2_max,
       '\n-min:\nV1:',v1_min,
       '\nV2:',v2_min
     )
# Out:
# -mean:
# V1: 0.43373525728862977
# V2: 1.9223531209912539
# -standard deviation:
# V1: 2.8417264052060993
# V2 5.866907488271995
# -max:
# V1: 6.8248
# V2: 12.9516
# -min:
# V1: -7.0421
# V2: -13.7731

# %% [markdown]
# ## Visualise the data

# %%
plt.xlabel('v1')
plt.ylabel('v2')
plt.scatter(v1D, v2D)
plt.show()

# %% [markdown]
# ##  K-Means clustering

# %%
V1_V2 = np.column_stack((v1D, v2D))


km_res = KMeans(n_clusters=2, n_init = 10).fit(V1_V2)
clusters = km_res.cluster_centers_
y_kmeans = km_res.predict(V1_V2)

 
plt.xlabel('V1')
plt.ylabel('V2')
plt.scatter(v1D,v2D, c=y_kmeans, cmap='inferno')
plt.scatter(clusters[:,0],clusters[:,1],s=200)

plt.show()

data['kmean'] = km_res.labels_
data['kmean'].value_counts()
# Out:
# C:\Users\majd\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# 1    775
# 0    597
# Name: kmean, dtype: int64
